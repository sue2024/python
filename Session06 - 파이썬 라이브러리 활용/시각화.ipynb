# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
st01Data = pd.read_csv("../dataset/st0001data.csv", encoding = "ms949")
st02Data = pd.read_csv("../dataset/st0002data.csv", encoding = "ms949")

# %%
x=st01Data.WEEK
y=st02Data.MEAN_VOLUME

# %%
y
# Out:
# 0      158086
# 1      128312
# 2      127417
# 3      157127
# 4      197415
# 5      150261
# 6      151425
# 7      147848
# 8      145931
# 9      149626
# 10     147311
# 11     145426
# 12     138794
# 13     141270
# 14     133726
# 15     139517
# 16     132201
# 17     143831
# 18     136772
# 19     137546
# 20     157267
# 21     167130
# 22     137527
# 23     150257
# 24     138271
# 25     155637
# 26     184550
# 27     142598
# 28     154985
# 29     133998
# 30     140732
# 31     134564
# 32     150105
# 33     168303
# 34     149570
# 35     210006
# 36     195106
# 37     132870
# 38     129992
# 39     139629
# 40     127720
# 41     136559
# 42     124142
# 43     133493
# 44     155032
# 45     184242
# 46     378339
# 47    1400339
# 48     669711
# 49     294579
# 50     356271
# 51     422468
# 52     232523
# Name: MEAN_VOLUME, dtype: int64

# %%
# %matplotlib inline
#jupyter 환경에서 차트를 show 없이 자동으로 그려주는 매직명령어

xValue = st01Data.WEEK
yValue = st01Data.MEAN_VOLUME

plt.xticks(range(min(x), max(x),3)) #최댓값 최솟값범위 지정, 3씩 커짐
plt.xlabel("week") # x축 이름
plt.ylabel("avg value") # y축 이름
plt.title("weekly code") # 차트의 제목
plt.plot(xValue,yValue)

# %%
## xticks와 plot을 같이 해줘야함
plt.plot(xValue, yValue, "bo:", lw=2.5)

# %%
# 실습문제

# %%
featuresData = pd.read_csv("../dataset/feature_regression_example.csv", encoding = "ms949")

featuresData

featuresData2015 = featuresData.loc[featuresData.YEAR == 2015]

featuresData2015

# %matplotlib inline

yValue = featuresData2015.QTY
xValue =  featuresData2015.WEEK

plt.xticks(range(0, max(x),10))
plt.xlabel("week")
plt.ylabel("QTY")

plt.legend(loc=0)

plt.plot(xValue,yValue)
## xticks와 plot을 같이 해줘야함

# 선색상, 종류, 굵기 변경
plt.plot(xValue, yValue, "g-", lw=1)
# Out:
# No handles with labels found to put in legend.

# %% [markdown]
# # 시각화 차트의 이해

# %%
import matplotlib.pyplot as plt

# %%
st01Data = pd.read.csv("../dataset/")??????

# %%
xValue = st01Data.WEEK
yValue = st01Data.MEAN_VOLUME
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-4c92a1241967> in <module>
# ----> 1 xValue = st01Data.WEEK
#       2 yValue = st01Data.MEAN_VOLUME
#
# NameError: name 'st01Data' is not defined

# %%
x2Value = st02Data.WEEK
y2Value = st02Data.MEAN_VOLUME

# %%
plt.figure(figsize=(10,5)) # 10은 x축, 길이는 5

ax1 = fig.add_subplot(211) # 2행1열로 영역을 나누고 그중에 첫번째영역에  ax1이라는 그림을 그리겠따
ax1.polt(xValue,yValue,"b--", label="ST0001") # plot(선)을 그릴 때 라벨을 넣어줘야 한다~!
ax1.legend(loc=0)


ax2 = fig,add_subplot(212)
ax2.polt(x2Value,y2Value,"g")
ax2.legend(loc=0)

# %% [markdown]
# # 이중축 그리기 (이중축 : 축 하나를 공유하는 것)

# %%
plt.figure(figsize=(10,5)) # 10은 x축, 길이는 5

ax1 = fig.add_subplot(111) # 2행1열로 영역을 나누고 그중에 첫번째영역에  ax1이라는 그림을 그리겠따
ax1.polt(xValue,yValue,"b--", label="ST0001") # plot(선)을 그릴 때 라벨을 넣어줘야 한다~!
ax1.legend(loc=0)


ax2 = ax1.twinx() # x축을 같이 쓰겠다~!
ax2.polt(x2Value,y2Value,"g")
ax2.legend(loc=0)

# %%
#데이터 전처리
#병합 : concat, append
#FILLAN(0) FFILL BFILL 
# isnull()not
#null 처리하는 부분

# %%
# 시각화
# matplotlib라이브러리~
# plt.polt(x,y,"b--")
# 도화지라는 서브플롯을 생성 add_subplot(121)
# 도화지라는 컬럼들을 서로 비교할(이중축) -> 다른크기의 데이터를 한 차트에 보여줄때 사용?

# %%
## 1. 데이터 불러오기

# %%
pd.read_csv("../dataset/customer")
